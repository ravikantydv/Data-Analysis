# %%
import pandas as pd
data = pd.read_excel("sales.xlsx") 
data
# Out:
#           Market             Region  No_of_Orders    Profit      Sales
# 0         Africa     Western Africa           251 -12901.51   78476.06
# 1         Africa    Southern Africa            85  11768.58   51319.50
# 2         Africa       North Africa           182  21643.08   86698.89
# 3         Africa     Eastern Africa           110   8013.04   44182.60
# 4         Africa     Central Africa           103  15606.30   61689.99
# 5   Asia Pacific       Western Asia           382 -16766.90  124312.24
# 6   Asia Pacific      Southern Asia           469  67998.76  351806.60
# 7   Asia Pacific  Southeastern Asia           533  20948.84  329751.38
# 8   Asia Pacific            Oceania           646  54734.02  408002.98
# 9   Asia Pacific       Eastern Asia           414  72805.10  315390.77
# 10  Asia Pacific       Central Asia            37  -2649.76    8190.74
# 11        Europe     Western Europe           964  82091.27  656637.14
# ...

# %%
data.shape
# Out:
# (23, 5)

# %%
data.describe()
# Out:
#        No_of_Orders        Profit          Sales
# count     23.000000     23.000000      23.000000
# mean     366.478261  28859.944783  206285.108696
# std      246.590361  27701.193773  160589.886606
# min       37.000000 -16766.900000    8190.740000
# 25%      211.500000  12073.085000   82587.475000
# 50%      356.000000  20948.840000  170416.310000
# 75%      479.500000  45882.845000  290182.375000
# max      964.000000  82091.270000  656637.140000

# %%
data.head(2)
# Out:
#    Market           Region  No_of_Orders    Profit     Sales
# 0  Africa   Western Africa           251 -12901.51  78476.06
# 1  Africa  Southern Africa            85  11768.58  51319.50

# %%
data.tail(2)
# Out:
#    Market      Region  No_of_Orders    Profit      Sales
# 21   USCA  Central US           356  33697.43  170416.31
# 22   USCA      Canada            49   7246.62   26298.81

# %%
data.mean()
# Out:
# C:\Users\dell\AppData\Local\Temp/ipykernel_6856/531903386.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.mean()
# No_of_Orders       366.478261
# Profit           28859.944783
# Sales           206285.108696
# dtype: float64

# %%
data.median()
# Out:
# C:\Users\dell\AppData\Local\Temp/ipykernel_6856/4184645713.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.median()
# No_of_Orders       356.00
# Profit           20948.84
# Sales           170416.31
# dtype: float64

# %%
data2 = data[["Profit"]]
data2
# Out:
#       Profit
# 0  -12901.51
# 1   11768.58
# 2   21643.08
# 3    8013.04
# 4   15606.30
# 5  -16766.90
# 6   67998.76
# 7   20948.84
# 8   54734.02
# 9   72805.10
# 10  -2649.76
# 11  82091.27
# 12  18911.49
# 13  43237.44
# 14  25050.69
# 15  12377.59
# 16  74679.54
# 17  13529.59
# 18  44303.65
# 19  19991.83
# 20  47462.04
# 21  33697.43
# 22   7246.62

# %%
data2.mean()
# Out:
# Profit    28859.944783
# dtype: float64

# %%
data2.median()
# Out:
# Profit    20948.84
# dtype: float64

# %%
data3 = data[5:10:1]
data3
# Out:
#          Market             Region  No_of_Orders    Profit      Sales
# 5  Asia Pacific       Western Asia           382 -16766.90  124312.24
# 6  Asia Pacific      Southern Asia           469  67998.76  351806.60
# 7  Asia Pacific  Southeastern Asia           533  20948.84  329751.38
# 8  Asia Pacific            Oceania           646  54734.02  408002.98
# 9  Asia Pacific       Eastern Asia           414  72805.10  315390.77

# %%
(data["Profit"]>10).head()
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4     True
# Name: Profit, dtype: bool

# %%
(data["Profit"]>10).count()
# Out:
# 23

# %%
data["Profit"].max()
# Out:
# 82091.27

# %%
data["Profit"].min()
# Out:
# -16766.9

# %%
data.rename(columns={"Market":"Place"}, inplace=True)
#inplace IS USED FOR CHANGING THE VALUE IN THE WHOLE DATASET

# %%
data
# Out:
#            Place             Region  No_of_Orders    Profit      Sales
# 0         Africa     Western Africa           251 -12901.51   78476.06
# 1         Africa    Southern Africa            85  11768.58   51319.50
# 2         Africa       North Africa           182  21643.08   86698.89
# 3         Africa     Eastern Africa           110   8013.04   44182.60
# 4         Africa     Central Africa           103  15606.30   61689.99
# 5   Asia Pacific       Western Asia           382 -16766.90  124312.24
# 6   Asia Pacific      Southern Asia           469  67998.76  351806.60
# 7   Asia Pacific  Southeastern Asia           533  20948.84  329751.38
# 8   Asia Pacific            Oceania           646  54734.02  408002.98
# 9   Asia Pacific       Eastern Asia           414  72805.10  315390.77
# 10  Asia Pacific       Central Asia            37  -2649.76    8190.74
# 11        Europe     Western Europe           964  82091.27  656637.14
# ...

# %%
data = pd.read_excel("sales.xlsx", index_col=[0]) 
data
#FOR REMOVING THE INDEX
# Out:
#                          Region  No_of_Orders    Profit      Sales
# Market
# Africa           Western Africa           251 -12901.51   78476.06
# Africa          Southern Africa            85  11768.58   51319.50
# Africa             North Africa           182  21643.08   86698.89
# Africa           Eastern Africa           110   8013.04   44182.60
# Africa           Central Africa           103  15606.30   61689.99
# Asia Pacific       Western Asia           382 -16766.90  124312.24
# Asia Pacific      Southern Asia           469  67998.76  351806.60
# Asia Pacific  Southeastern Asia           533  20948.84  329751.38
# Asia Pacific            Oceania           646  54734.02  408002.98
# Asia Pacific       Eastern Asia           414  72805.10  315390.77
# Asia Pacific       Central Asia            37  -2649.76    8190.74
# Europe           Western Europe           964  82091.27  656637.14
# Europe          Southern Europe           338  18911.49  215703.93
# ...

# %%
data.reset_index(inplace = True)

# %%
data.reset_index(['Market', 'Region'], inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6856/2995539414.py in <module>
# ----> 1 data.reset_index(['Market', 'Region'], inplace = True)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    5743             if not isinstance(level, (tuple, list)):
#    5744                 level = [level]
# -> 5745             level = [self.index._get_level_number(lev) for lev in level]
#    5746             if len(level) < self.index.nlevels:
#    5747                 new_index = self.index.droplevel(level)
#
# ...

# %%
data.loc[['Africa', 'Europe']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6856/1414816142.py in <module>
# ----> 1 data.loc[['Africa', 'Europe']]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1151                     raise ValueError("Cannot index with multidimensional key")
#    1152
# -> 1153                 return self._getitem_iterable(key, axis=axis)
#    1154
#    1155             # nested tuple slicing
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_iterable(self, key, axis)
#    1091
# ...

# %%
data.drop('Africa')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6856/4110275934.py in <module>
# ----> 1 data.drop('Africa')
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4899                 weight  1.0     0.8
#    4900         """
# -> 4901         return super().drop(
#    4902             labels=labels,
#    4903             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
# ...

# %%
data
